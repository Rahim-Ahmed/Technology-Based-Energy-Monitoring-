# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('All_Data.csv')

# %%
df
# Out:
#          Timestamp  Current(mA)  Voltage(V)  Power(W)  kWh per Minute  \
# 0    4/1/2024 2:32          370       247.4      79.4        0.001323
# 1    4/1/2024 2:33          370       247.4      79.4        0.001323
# 2    4/1/2024 2:34          370       247.4      79.4        0.001323
# 3    4/1/2024 2:35          370       247.4      79.4        0.001323
# 4    4/1/2024 2:36          370       247.4      79.4        0.001323
# ..             ...          ...         ...       ...             ...
# 335  4/5/2024 0:34          538       244.1     125.0        0.002083
# 336  4/5/2024 0:35          538       244.1     125.0        0.002083
# 337  4/5/2024 0:36          538       244.1     125.0        0.002083
# 338  4/5/2024 0:37          430       246.0      93.2        0.001553
# 339  4/5/2024 0:38          536       244.6     120.0        0.002000
#
#      Cost per Minute
# 0           0.011698
# 1           0.011698
# 2           0.011698
# 3           0.011698
# 4           0.011698
# ..               ...
# 335         0.018417
# 336         0.018417
# 337         0.018417
# 338         0.013731
# 339         0.017680
#
# [340 rows x 6 columns]

# %%
df.describe()
# Out:
#        Current(mA)  Voltage(V)    Power(W)  kWh per Minute  Cost per Minute
# count   340.000000  340.000000  340.000000      340.000000       340.000000
# mean    360.950000  246.955588   77.617647        0.001294         0.011436
# std      76.960438    2.417158   19.504952        0.000325         0.002874
# min     267.000000  240.900000   53.300000        0.000888         0.007853
# 25%     298.000000  245.000000   64.100000        0.001068         0.009444
# 50%     343.000000  247.400000   75.100000        0.001252         0.011065
# 75%     407.000000  248.800000   85.300000        0.001422         0.012568
# max     730.000000  251.700000  178.200000        0.002970         0.026255

# %%
sns.set_theme(style="whitegrid", palette="pastel")

sns.set(rc={'figure.figsize':(30, 10)})  

# Plot the responses for different events and regions
sns.lineplot(x="Timestamp", y="Current(mA)",data=df)

# Display the plot
plt.show()

# %%
sns.set_theme(style="whitegrid", palette="pastel")

sns.set(rc={'figure.figsize':(30, 10)})  

# Plot the responses for different events and regions
sns.lineplot(x="Timestamp", y="Voltage(V)",data=df)

# Display the plot
plt.show()

# %%
sns.set_theme(style="whitegrid", palette="pastel")

sns.set(rc={'figure.figsize':(30, 10)})  

# Plot the responses for different events and regions
sns.lineplot(x="Timestamp", y="Power(W)",data=df)

# Display the plot
plt.show()
